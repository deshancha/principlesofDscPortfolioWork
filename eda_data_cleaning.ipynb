# %% [markdown]
# # EDA - Cleaning and Procesing

# %%
import sys
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv

sys.path.insert(0, os.path.abspath('src'))

# DI
from di.container import AppContainer

load_dotenv()
# Out:
# True

# %% [markdown]
# ## DI Init

# %%
container = AppContainer()
container.config.from_dict({
    "aws": {
        "s3_bucket_name": os.getenv("AWS_S3_BUCKET_NAME"),
        "region_name": os.getenv("AWS_REGION_NAME")
    },
    "db": {
        "connection_string": os.getenv("DB_CONNECTION_STRING")
    }
})

rds_to_pandas_usecase = container.rds_to_pandas_usecase()

# %% [markdown]
# ## Fetch Data from AWS RDS

# %%
# BTC-USD ETH-USD SOL-USD BNB-USD DOGE-USD"
TICKER = "BTC-USD" 
TABLE_NAME = os.getenv("AWS_RDS_TABLE_NAME", "crypto_market_data")

df = rds_to_pandas_usecase.execute(ticker=TICKER, table_name=TABLE_NAME)
print(f"Fetched {len(df)} records for {TICKER}.")
df.head()
# Out:
# 2026-04-01 15:52:10,223 | INFO     | [App] Starting RDS -> Pandas retrieval for ticker: BTC-USD
# 2026-04-01 15:52:18,278 | INFO     | [App] Successfully loaded 820 records into Pandas DataFrame
#
# --- Data for BTC-USD ---
#    id   ticker timestamp_utc    open_price    high_price     low_price  \
# 0   1  BTC-USD    2024-01-01  42280.234375  44175.437500  42214.976562
# 1   2  BTC-USD    2024-01-02  44187.140625  45899.707031  44176.949219
# 2   3  BTC-USD    2024-01-03  44961.601562  45503.242188  40813.535156
# 3   4  BTC-USD    2024-01-04  42855.816406  44770.023438  42675.175781
# 4   5  BTC-USD    2024-01-05  44192.980469  44353.285156  42784.718750
#
#     close_price       volume         source
# 0  44167.332031  18426978443  yahoo_finance
# 1  44957.968750  39335274536  yahoo_finance
# 2  42848.175781  46342323118  yahoo_finance
# 3  44179.921875  30448091210  yahoo_finance
# 4  44162.691406  32336029347  yahoo_finance
# Fetched 820 records for BTC-USD.
#    id   ticker timestamp_utc    open_price    high_price     low_price  \
# 0   1  BTC-USD    2024-01-01  42280.234375  44175.437500  42214.976562
# 1   2  BTC-USD    2024-01-02  44187.140625  45899.707031  44176.949219
# 2   3  BTC-USD    2024-01-03  44961.601562  45503.242188  40813.535156
# 3   4  BTC-USD    2024-01-04  42855.816406  44770.023438  42675.175781
# 4   5  BTC-USD    2024-01-05  44192.980469  44353.285156  42784.718750
#
#     close_price       volume         source
# 0  44167.332031  18426978443  yahoo_finance
# 1  44957.968750  39335274536  yahoo_finance
# 2  42848.175781  46342323118  yahoo_finance
# 3  44179.921875  30448091210  yahoo_finance
# 4  44162.691406  32336029347  yahoo_finance

# %% [markdown]
# ## Data Cleaning
#
# ### Rename Columns and Drop Not need

# %%
df = df.drop(columns=['source'])

rename_to = {
    'timestamp_utc': 'date',
    'open_price': 'open',
    'high_price': 'high',
    'low_price': 'low',
    'close_price': 'close'
}
df = df.rename(columns=rename_to)
df.head()
# Out:
#   Cell In[60], line 5
#     'open_price': 'open',
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Handle Missing Values

# %%
missing_map = df.isnull()

# sum of columns -> final column total
missing_total = missing_map.sum().sum()
print(f"Initial missing values: {missing_total}")

if missing_total > 0:
    df = df.fillna(method='ffill')
    print(f"Total Missing after fill: {df.isnull().sum().sum()}")
else :
    print("No Missing")
# Out:
# Initial missing values: 0
# No Missing

# %% [markdown]
# ### Convert Data Types

# %%
df.dtypes
# Out:
# id                        int64
# ticker                   object
# timestamp_utc    datetime64[ns]
# open                    float64
# high                    float64
# low                     float64
# close                   float64
# volume                   object
# dtype: object

# %% [markdown]
# Convert Volume Column to Numberic

# %%
df['volume'] = pd.to_numeric(df['volume'], errors='coerce')
df.dtypes
# Out:
# id                        int64
# ticker                   object
# timestamp_utc    datetime64[ns]
# open                    float64
# high                    float64
# low                     float64
# close                   float64
# volume                    int64
# dtype: object

# %% [markdown]
# ## 4. Line-Chart of Bitcoin

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
plt.plot(df['timestamp_utc'],
 df['close'], label='price')
plt.title(f"{TICKER} Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
